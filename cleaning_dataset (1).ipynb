# %%
#first we import numpy and pandas library to understand dataset in depth
import numpy as np
import pandas as pd

# %%
dataset=pd.read_csv("train.csv")

# %%
dataset.head()
#head
#thus again
# Out:
#         ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0  0x4607     INDORES13DEL02                   37                     4.9
# 1  0xb379     BANGRES18DEL02                   34                     4.5
# 2  0x5d6d     BANGRES19DEL01                   23                     4.4
# 3  0x7a6a    COIMBRES13DEL02                   38                     4.7
# 4  0x70a2     CHENRES12DEL01                   32                     4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %%
#to display all the rows we have to increase display size
# this will display more rows and columns
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 50)
dataset.head(100)
# Out:
#          ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0   0x4607     INDORES13DEL02                   37                     4.9
# 1   0xb379     BANGRES18DEL02                   34                     4.5
# 2   0x5d6d     BANGRES19DEL01                   23                     4.4
# 3   0x7a6a    COIMBRES13DEL02                   38                     4.7
# 4   0x70a2     CHENRES12DEL01                   32                     4.6
# 5   0x9bb4      HYDRES09DEL03                   22                     4.8
# 6   0x95b4   RANCHIRES15DEL01                   33                     4.7
# 7   0x9eb2      MYSRES15DEL02                   35                     4.6
# 8   0x1102      HYDRES05DEL02                   22                     4.8
# 9   0xcdcd      DEHRES17DEL01                   36                     4.2
# 10  0xd987      KOCRES16DEL01                   21                     4.7
# ...

# %%
#to check the datatype of dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45593 entries, 0 to 45592
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45593 non-null  object
#  1   Delivery_person_ID           45593 non-null  object
#  2   Delivery_person_Age          45593 non-null  object
#  3   Delivery_person_Ratings      45593 non-null  object
#  4   Restaurant_latitude          45593 non-null  float64
#  5   Restaurant_longitude         45593 non-null  float64
#  6   Delivery_location_latitude   45593 non-null  float64
#  7   Delivery_location_longitude  45593 non-null  float64
#  8   Order_Date                   45593 non-null  object
#  9   Time_Orderd                  45593 non-null  object
#  10  Time_Order_picked            45593 non-null  object
#  11  Weatherconditions            45593 non-null  object
# ...

# %%
null_count=dataset.isnull().sum()
null_count
# Out:
# ID                             0
# Delivery_person_ID             0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Order_Date                     0
# Time_Orderd                    0
# Time_Order_picked              0
# Weatherconditions              0
# Road_traffic_density           0
# Vehicle_condition              0
# Type_of_order                  0
# Type_of_vehicle                0
# multiple_deliveries            0
# Festival                       0
# City                           0
# Time_taken(min)                0
# dtype: int64

# %%
#if we look in a dataset, their are some null value present but not correctly recognised by 
#isnull() function because it is present as (Nan) and this is treated as a string in pandas
#so we will convert NAN int nan to check null values in a dataset

# %%
#dataset=dataset.replace("NaN", np.nan, inplace=True)

# %%
#null_count_new=dataset.isnull().sum()
#null_count_new

# %%
#to resolve this error
dataset = dataset.replace('NaN', np.nan, regex=True)

# %%
null_count_new=dataset.isnull().sum()
null_count_new
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weatherconditions               616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken(min)                   0
# dtype: int64

# %%
dataset["Time_taken(min)"] = dataset["Time_taken(min)"].str.replace("(", "")
dataset["Time_taken(min)"] = dataset["Time_taken(min)"].str.replace("min", "")
dataset["Time_taken(min)"] = dataset["Time_taken(min)"].str.replace(")", "")
dataset["Time_taken(min)"]= dataset["Time_taken(min)"].astype("Int64")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45593 entries, 0 to 45592
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45593 non-null  object
#  1   Delivery_person_ID           45593 non-null  object
#  2   Delivery_person_Age          43739 non-null  object
#  3   Delivery_person_Ratings      43685 non-null  object
#  4   Restaurant_latitude          45593 non-null  float64
#  5   Restaurant_longitude         45593 non-null  float64
#  6   Delivery_location_latitude   45593 non-null  float64
#  7   Delivery_location_longitude  45593 non-null  float64
#  8   Order_Date                   45593 non-null  object
#  9   Time_Orderd                  43862 non-null  object
#  10  Time_Order_picked            45593 non-null  object
#  11  Weatherconditions            44977 non-null  object
# ...

# %%
dataset["Delivery_person_Age"] = pd.to_numeric(dataset["Delivery_person_Age"], errors='coerce').astype("Int64")
dataset["multiple_deliveries"] = pd.to_numeric(dataset["multiple_deliveries"], errors='coerce').astype("Int64")

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45593 entries, 0 to 45592
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45593 non-null  object
#  1   Delivery_person_ID           45593 non-null  object
#  2   Delivery_person_Age          43739 non-null  Int64
#  3   Delivery_person_Ratings      43685 non-null  object
#  4   Restaurant_latitude          45593 non-null  float64
#  5   Restaurant_longitude         45593 non-null  float64
#  6   Delivery_location_latitude   45593 non-null  float64
#  7   Delivery_location_longitude  45593 non-null  float64
#  8   Order_Date                   45593 non-null  object
#  9   Time_Orderd                  43862 non-null  object
#  10  Time_Order_picked            45593 non-null  object
#  11  Weatherconditions            44977 non-null  object
# ...

# %%
dataset["Time_taken(min)"]=dataset["Time_taken(min)"].astype("Int64")

# %%
dataset.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weatherconditions               616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken(min)                   0
# dtype: int64

# %%
dataset.head(100)
# Out:
#          ID Delivery_person_ID  Delivery_person_Age Delivery_person_Ratings  \
# 0   0x4607     INDORES13DEL02                    37                     4.9
# 1   0xb379     BANGRES18DEL02                    34                     4.5
# 2   0x5d6d     BANGRES19DEL01                    23                     4.4
# 3   0x7a6a    COIMBRES13DEL02                    38                     4.7
# 4   0x70a2     CHENRES12DEL01                    32                     4.6
# 5   0x9bb4      HYDRES09DEL03                    22                     4.8
# 6   0x95b4   RANCHIRES15DEL01                    33                     4.7
# 7   0x9eb2      MYSRES15DEL02                    35                     4.6
# 8   0x1102      HYDRES05DEL02                    22                     4.8
# 9   0xcdcd      DEHRES17DEL01                    36                     4.2
# 10  0xd987      KOCRES16DEL01                    21                     4.7
# ...

# %%
mean=dataset["Delivery_person_Age"].mean()
mean=np.int64(mean)
#dataset['Delivery_person_Age']=dataset['Delivery_person_Age'].replace("<NA>",0,inplace=True)
dataset['Delivery_person_Age'].fillna(0,inplace=True)

dataset['Delivery_person_Age']=dataset['Delivery_person_Age'].replace(0,mean)

# %%
dataset.head(100)
#head
#this again
# Out:
#          ID Delivery_person_ID  Delivery_person_Age Delivery_person_Ratings  \
# 0   0x4607     INDORES13DEL02                    37                     4.9
# 1   0xb379     BANGRES18DEL02                    34                     4.5
# 2   0x5d6d     BANGRES19DEL01                    23                     4.4
# 3   0x7a6a    COIMBRES13DEL02                    38                     4.7
# 4   0x70a2     CHENRES12DEL01                    32                     4.6
# 5   0x9bb4      HYDRES09DEL03                    22                     4.8
# 6   0x95b4   RANCHIRES15DEL01                    33                     4.7
# 7   0x9eb2      MYSRES15DEL02                    35                     4.6
# 8   0x1102      HYDRES05DEL02                    22                     4.8
# 9   0xcdcd      DEHRES17DEL01                    36                     4.2
# 10  0xd987      KOCRES16DEL01                    21                     4.7
# ...

# %%
dataset["Delivery_person_Ratings"] = pd.to_numeric(dataset["Delivery_person_Ratings"], errors='coerce').astype("float64")
#dataset["Delivery_person_Ratings"] = dataset["Delivery_person_Ratings"].astype("int")
#dataset["Delivery_person_Ratings"] = pd.to_numeric(dataset["Delivery_person_Ratings"], errors='coerc

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45593 entries, 0 to 45592
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45593 non-null  object
#  1   Delivery_person_ID           45593 non-null  object
#  2   Delivery_person_Age          45593 non-null  Int64
#  3   Delivery_person_Ratings      43685 non-null  float64
#  4   Restaurant_latitude          45593 non-null  float64
#  5   Restaurant_longitude         45593 non-null  float64
#  6   Delivery_location_latitude   45593 non-null  float64
#  7   Delivery_location_longitude  45593 non-null  float64
#  8   Order_Date                   45593 non-null  object
#  9   Time_Orderd                  43862 non-null  object
#  10  Time_Order_picked            45593 non-null  object
#  11  Weatherconditions            44977 non-null  object
# ...

# %%
import seaborn as sns

# %%
correlation=dataset.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\ayush\Minor\Minor\cleaning_dataset (1).ipynb Cell 23 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ayush/Minor/Minor/cleaning_dataset%20%281%29.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> correlation=dataset.corr()
#
# File c:\Python311\Lib\site-packages\pandas\core\frame.py:10707, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10705 cols = data.columns
#   10706 idx = cols.copy()
# > 10707 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10709 if method == "pearson":
#   10710     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Python311\Lib\site-packages\pandas\core\frame.py:1892, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1890 if dtype is not None:
#    1891     dtype = np.dtype(dtype)
# ...

# %%
correlation
# Out:
#                              Delivery_person_Age  Delivery_person_Ratings  \
# Delivery_person_Age                     1.000000                -0.067939
# Delivery_person_Ratings                -0.067939                 1.000000
# Restaurant_latitude                    -0.001955                -0.007792
# Restaurant_longitude                   -0.006796                -0.014203
# Delivery_location_latitude              0.002359                -0.010318
# Delivery_location_longitude            -0.000593                -0.013552
# Vehicle_condition                       0.001049                 0.034581
# multiple_deliveries                     0.113321                -0.117647
# Time_taken(min)                         0.292708                -0.338790
#
#                              Restaurant_latitude  Restaurant_longitude  \
# Delivery_person_Age                    -0.001955             -0.006796
# Delivery_person_Ratings                -0.007792             -0.014203
# ...

# %%
dataset.describe()
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# count              45593.0             43685.000000         45593.000000
# mean             29.544075                 4.633780            17.017729
# std               5.696793                 0.334716             8.185109
# min                   15.0                 1.000000           -30.905562
# 25%                   25.0                 4.500000            12.933284
# 50%                   29.0                 4.700000            18.546947
# 75%                   34.0                 4.900000            22.728163
# max                   50.0                 6.000000            30.914057
#
#        Restaurant_longitude  Delivery_location_latitude  \
# count          45593.000000                45593.000000
# mean              70.231332                   17.465186
# std               22.883647                    7.335122
# min              -88.366217                    0.010000
# ...

# %%
dataset.head()
# Out:
#         ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0x4607     INDORES13DEL02                    37                      4.9
# 1  0xb379     BANGRES18DEL02                    34                      4.5
# 2  0x5d6d     BANGRES19DEL01                    23                      4.4
# 3  0x7a6a    COIMBRES13DEL02                    38                      4.7
# 4  0x70a2     CHENRES12DEL01                    32                      4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
# ...

# %%
dataset.describe(include='object')
# Out:
#              ID Delivery_person_ID  Order_Date Time_Orderd Time_Order_picked  \
# count     45593              45593       45593       43862             45593
# unique    45593               1320          44         176               193
# top     0x4607     PUNERES01DEL01   15-03-2022    21:55:00          21:30:00
# freq          1                 67        1192         461               496
#
#        Weatherconditions Road_traffic_density Type_of_order Type_of_vehicle  \
# count              44977                44992         45593           45593
# unique                 6                    4             4               4
# top       conditions Fog                 Low         Snack      motorcycle
# freq                7654                15477         11533           26435
#
#        Festival            City
# count     45365           44393
# unique        2               3
# top         No   Metropolitian
# freq      44469           34093

# %%
dataset.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weatherconditions               616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken(min)                   0
# dtype: int64

# %%
dataset.head(100)
# Out:
#          ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0   0x4607     INDORES13DEL02                    37                      4.9
# 1   0xb379     BANGRES18DEL02                    34                      4.5
# 2   0x5d6d     BANGRES19DEL01                    23                      4.4
# 3   0x7a6a    COIMBRES13DEL02                    38                      4.7
# 4   0x70a2     CHENRES12DEL01                    32                      4.6
# 5   0x9bb4      HYDRES09DEL03                    22                      4.8
# 6   0x95b4   RANCHIRES15DEL01                    33                      4.7
# 7   0x9eb2      MYSRES15DEL02                    35                      4.6
# 8   0x1102      HYDRES05DEL02                    22                      4.8
# 9   0xcdcd      DEHRES17DEL01                    36                      4.2
# 10  0xd987      KOCRES16DEL01                    21                      4.7
# ...

# %%
#changing the data type of Delivery_person_Ratings from obj to int
dataset["Delivery_person_Ratings"] = dataset["Delivery_person_Ratings"].astype("float")

# %%
#finding mean of "Delivery_person_Ratings"
mean=dataset["Delivery_person_Ratings"].mean()
mean
# Out:
# 4.633780473846858

# %%
#filing the Delivery_person_Ratings empty column
dataset["Delivery_person_Ratings"]=dataset["Delivery_person_Ratings"].replace(np.nan,mean)

# %%
dataset.head(100)
# Out:
#          ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0   0x4607     INDORES13DEL02                    37                  4.90000
# 1   0xb379     BANGRES18DEL02                    34                  4.50000
# 2   0x5d6d     BANGRES19DEL01                    23                  4.40000
# 3   0x7a6a    COIMBRES13DEL02                    38                  4.70000
# 4   0x70a2     CHENRES12DEL01                    32                  4.60000
# 5   0x9bb4      HYDRES09DEL03                    22                  4.80000
# 6   0x95b4   RANCHIRES15DEL01                    33                  4.70000
# 7   0x9eb2      MYSRES15DEL02                    35                  4.60000
# 8   0x1102      HYDRES05DEL02                    22                  4.80000
# 9   0xcdcd      DEHRES17DEL01                    36                  4.20000
# 10  0xd987      KOCRES16DEL01                    21                  4.70000
# ...

# %%
dataset.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_Ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weatherconditions               616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken(min)                   0
# dtype: int64

# %%
#mode of wether_condition
#ode=dataset["Weatherconditions"].mode()
#ode

# %%
#replaving missing value with the mod of Wetherconditions in the column
mode_value = dataset['Weatherconditions'].mode().iloc[0]
mode_value

# Replace NaN values with the mode
dataset['Weatherconditions'].fillna(mode_value, inplace=True)

# %%
dataset.head(100)
# Out:
#          ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0   0x4607     INDORES13DEL02                    37                  4.90000
# 1   0xb379     BANGRES18DEL02                    34                  4.50000
# 2   0x5d6d     BANGRES19DEL01                    23                  4.40000
# 3   0x7a6a    COIMBRES13DEL02                    38                  4.70000
# 4   0x70a2     CHENRES12DEL01                    32                  4.60000
# 5   0x9bb4      HYDRES09DEL03                    22                  4.80000
# 6   0x95b4   RANCHIRES15DEL01                    33                  4.70000
# 7   0x9eb2      MYSRES15DEL02                    35                  4.60000
# 8   0x1102      HYDRES05DEL02                    22                  4.80000
# 9   0xcdcd      DEHRES17DEL01                    36                  4.20000
# 10  0xd987      KOCRES16DEL01                    21                  4.70000
# ...

# %%
dataset.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_Ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weatherconditions                 0
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken(min)                   0
# dtype: int64

# %%
#replaving missing value with the mod of Road_traffic density in the column
mode_value = dataset['Road_traffic_density'].mode().iloc[0]
mode_value

# Replace NaN values with the mode
dataset['Road_traffic_density'].fillna(mode_value, inplace=True)

# %%
dataset.head(100)
# Out:
#          ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0   0x4607     INDORES13DEL02                    37                  4.90000
# 1   0xb379     BANGRES18DEL02                    34                  4.50000
# 2   0x5d6d     BANGRES19DEL01                    23                  4.40000
# 3   0x7a6a    COIMBRES13DEL02                    38                  4.70000
# 4   0x70a2     CHENRES12DEL01                    32                  4.60000
# 5   0x9bb4      HYDRES09DEL03                    22                  4.80000
# 6   0x95b4   RANCHIRES15DEL01                    33                  4.70000
# 7   0x9eb2      MYSRES15DEL02                    35                  4.60000
# 8   0x1102      HYDRES05DEL02                    22                  4.80000
# 9   0xcdcd      DEHRES17DEL01                    36                  4.20000
# 10  0xd987      KOCRES16DEL01                    21                  4.70000
# ...

# %%
dataset.info(
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45593 entries, 0 to 45592
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45593 non-null  object
#  1   Delivery_person_ID           45593 non-null  object
#  2   Delivery_person_Age          45593 non-null  Int64
#  3   Delivery_person_Ratings      45593 non-null  float64
#  4   Restaurant_latitude          45593 non-null  float64
#  5   Restaurant_longitude         45593 non-null  float64
#  6   Delivery_location_latitude   45593 non-null  float64
#  7   Delivery_location_longitude  45593 non-null  float64
#  8   Order_Date                   45593 non-null  object
#  9   Time_Orderd                  43862 non-null  object
#  10  Time_Order_picked            45593 non-null  object
#  11  Weatherconditions            45593 non-null  object
# ...

# %%
#finding mean in multiple deliveries column
mode=dataset["multiple_deliveries"].mode().iloc[0]
mode
#filling dataset with the mode value
dataset["multiple_deliveries"].fillna(mode,inplace=True)

# %%
dataset.head(100)
# Out:
#          ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0   0x4607     INDORES13DEL02                    37                  4.90000
# 1   0xb379     BANGRES18DEL02                    34                  4.50000
# 2   0x5d6d     BANGRES19DEL01                    23                  4.40000
# 3   0x7a6a    COIMBRES13DEL02                    38                  4.70000
# 4   0x70a2     CHENRES12DEL01                    32                  4.60000
# 5   0x9bb4      HYDRES09DEL03                    22                  4.80000
# 6   0x95b4   RANCHIRES15DEL01                    33                  4.70000
# 7   0x9eb2      MYSRES15DEL02                    35                  4.60000
# 8   0x1102      HYDRES05DEL02                    22                  4.80000
# 9   0xcdcd      DEHRES17DEL01                    36                  4.20000
# 10  0xd987      KOCRES16DEL01                    21                  4.70000
# ...

# %%
dataset.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_Ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weatherconditions                 0
# Road_traffic_density              0
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries               0
# Festival                        228
# City                           1200
# Time_taken(min)                   0
# dtype: int64

# %%
#finding mean in Festivsal column
mode=dataset["Festival"].mode().iloc[0]
mode
#filling dataset with the mode value
dataset["Festival"].fillna(mode,inplace=True)

# %%
dataset.head(100)
# Out:
#          ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0   0x4607     INDORES13DEL02                    37                  4.90000
# 1   0xb379     BANGRES18DEL02                    34                  4.50000
# 2   0x5d6d     BANGRES19DEL01                    23                  4.40000
# 3   0x7a6a    COIMBRES13DEL02                    38                  4.70000
# 4   0x70a2     CHENRES12DEL01                    32                  4.60000
# 5   0x9bb4      HYDRES09DEL03                    22                  4.80000
# 6   0x95b4   RANCHIRES15DEL01                    33                  4.70000
# 7   0x9eb2      MYSRES15DEL02                    35                  4.60000
# 8   0x1102      HYDRES05DEL02                    22                  4.80000
# 9   0xcdcd      DEHRES17DEL01                    36                  4.20000
# 10  0xd987      KOCRES16DEL01                    21                  4.70000
# ...

# %%
dataset.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_Ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weatherconditions                 0
# Road_traffic_density              0
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries               0
# Festival                          0
# City                           1200
# Time_taken(min)                   0
# dtype: int64

# %%
#finding mean in City column
mode=dataset["Festival"].mode().iloc[0]
mode
#filling dataset with the mode value
dataset["City"].fillna(mode,inplace=True)

# %%
dataset.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_Ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weatherconditions                 0
# Road_traffic_density              0
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries               0
# Festival                          0
# City                              0
# Time_taken(min)                   0
# dtype: int64

# %%
#finding mean in City column
mode=dataset["Time_Orderd"].mode().iloc[0]
mode
#filling dataset with the mode value
dataset["Time_Orderd"].fillna(mode,inplace=True)

# %%
dataset.isnull().sum()
# Out:
# ID                             0
# Delivery_person_ID             0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Order_Date                     0
# Time_Orderd                    0
# Time_Order_picked              0
# Weatherconditions              0
# Road_traffic_density           0
# Vehicle_condition              0
# Type_of_order                  0
# Type_of_vehicle                0
# multiple_deliveries            0
# Festival                       0
# City                           0
# Time_taken(min)                0
# dtype: int64

# %%
dataset[["Delivery_person_Ratings","Time_taken(min)"]].corr()
# Out:
#                          Delivery_person_Ratings  Time_taken(min)
# Delivery_person_Ratings                 1.000000        -0.331115
# Time_taken(min)                        -0.331115         1.000000

# %%
dataset.corr()
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_17516\2191645083.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset.corr()
#                              Delivery_person_Age  Delivery_person_Ratings  \
# Delivery_person_Age                     1.000000                -0.067876
# Delivery_person_Ratings                -0.067876                 1.000000
# Restaurant_latitude                    -0.001955                -0.007223
# Restaurant_longitude                   -0.006796                -0.013037
# Delivery_location_latitude              0.002359                -0.010105
# Delivery_location_longitude            -0.000593                -0.013276
# Vehicle_condition                       0.001049                 0.033119
# multiple_deliveries                     0.110898                -0.113169
# ...

# %%
dataset.isnull().sum()
# Out:
# ID                             0
# Delivery_person_ID             0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Order_Date                     0
# Time_Orderd                    0
# Time_Order_picked              0
# Weatherconditions              0
# Road_traffic_density           0
# Vehicle_condition              0
# Type_of_order                  0
# Type_of_vehicle                0
# multiple_deliveries            0
# Festival                       0
# City                           0
# Time_taken(min)                0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45593 entries, 0 to 45592
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45593 non-null  object
#  1   Delivery_person_ID           45593 non-null  object
#  2   Delivery_person_Age          45593 non-null  Int64
#  3   Delivery_person_Ratings      45593 non-null  float64
#  4   Restaurant_latitude          45593 non-null  float64
#  5   Restaurant_longitude         45593 non-null  float64
#  6   Delivery_location_latitude   45593 non-null  float64
#  7   Delivery_location_longitude  45593 non-null  float64
#  8   Order_Date                   45593 non-null  object
#  9   Time_Orderd                  45593 non-null  object
#  10  Time_Order_picked            45593 non-null  object
#  11  Weatherconditions            45593 non-null  object
# ...

# %%
df=pd.DataFrame(dataset)

# %%
df.drop(columns=['ID','Delivery_person_ID'],inplace=True)

# %%
dataset=df

# %%
dataset.head(50)
# Out:
#     Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                    37                  4.90000            22.745049
# 1                    34                  4.50000            12.913041
# 2                    23                  4.40000            12.914264
# 3                    38                  4.70000            11.003669
# 4                    32                  4.60000            12.972793
# 5                    22                  4.80000            17.431668
# 6                    33                  4.70000            23.369746
# 7                    35                  4.60000            12.352058
# 8                    22                  4.80000            17.433809
# 9                    36                  4.20000            30.327968
# 10                   21                  4.70000            10.003064
# 11                   23                  4.70000            18.562450
# ...

# %%
sns.pairplot(data=dataset)
# Out:
# C:\Users\ayush\anaconda3\Lib\site-packages\seaborn\distributions.py:499: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   pd.Index(edges, name="edges"),
# C:\Users\ayush\anaconda3\Lib\site-packages\seaborn\distributions.py:500: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   pd.Index(widths, name="widths"),
# C:\Users\ayush\anaconda3\Lib\site-packages\seaborn\distributions.py:499: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   pd.Index(edges, name="edges"),
# ...

# %%
# sns.set(style="whitegrid")  # Optional: Set a grid style
# sns.regplot(x='Delivery_person_Age', y='Time_taken(min)', marker='o', color='b', scatter_kws={"s": 100},data=dataset)  # Customize plot appearance

# # Add labels and a title
# plt.xlabel("X-axis Label")
# plt.ylabel("Y-axis Label")
# plt.title("Regression Plot")
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45593 entries, 0 to 45592
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Delivery_person_Age          45593 non-null  Int64
#  1   Delivery_person_Ratings      45593 non-null  float64
#  2   Restaurant_latitude          45593 non-null  float64
#  3   Restaurant_longitude         45593 non-null  float64
#  4   Delivery_location_latitude   45593 non-null  float64
#  5   Delivery_location_longitude  45593 non-null  float64
#  6   Order_Date                   45593 non-null  object
#  7   Time_Orderd                  45593 non-null  object
#  8   Time_Order_picked            45593 non-null  object
#  9   Weatherconditions            45593 non-null  object
#  10  Road_traffic_density         45593 non-null  object
#  11  Vehicle_condition            45593 non-null  int64
# ...

# %%
dataset['Time_Orderd'] = pd.to_datetime(dataset['Time_Orderd'], format='%H:%M:%S', errors='coerce')

# %%
dataset['Time_Order_picked'] = pd.to_datetime(dataset['Time_Order_picked'], format='%H:%M:%S', errors='coerce')

# %%
df=pd.DataFrame(dataset)

#df['Food_Preparation_Time'] = (df['Time_Order_picked'] - df['Time_Orderd']).dt.total_seconds()

# %%
df.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                   37                      4.9            22.745049
# 1                   34                      4.5            12.913041
# 2                   23                      4.4            12.914264
# 3                   38                      4.7            11.003669
# 4                   32                      4.6            12.972793
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             75.892471                   22.765049
# 1             77.683237                   13.043041
# 2             77.678400                   12.924264
# 3             76.976494                   11.053669
# 4             80.249982                   13.012793
#
#    Delivery_location_longitude  Order_Date         Time_Orderd  \
# 0                    75.912471  19-03-2022 1900-01-01 11:30:00
# 1                    77.813237  25-03-2022 1900-01-01 19:45:00
# ...

# %%
df['Food_Preparation_Time_minutes'] = (df['Time_Order_picked'] - df['Time_Orderd']).dt.total_seconds() / 60

# %%
df.head(50)
# Out:
#     Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                    37                  4.90000            22.745049
# 1                    34                  4.50000            12.913041
# 2                    23                  4.40000            12.914264
# 3                    38                  4.70000            11.003669
# 4                    32                  4.60000            12.972793
# 5                    22                  4.80000            17.431668
# 6                    33                  4.70000            23.369746
# 7                    35                  4.60000            12.352058
# 8                    22                  4.80000            17.433809
# 9                    36                  4.20000            30.327968
# 10                   21                  4.70000            10.003064
# 11                   23                  4.70000            18.562450
# ...

# %%
df['Delivery_traveling_time'] = df['Time_taken(min)']-df['Food_Preparation_Time_minutes']

# %%
df.head(50)
# Out:
#     Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                    37                  4.90000            22.745049
# 1                    34                  4.50000            12.913041
# 2                    23                  4.40000            12.914264
# 3                    38                  4.70000            11.003669
# 4                    32                  4.60000            12.972793
# 5                    22                  4.80000            17.431668
# 6                    33                  4.70000            23.369746
# 7                    35                  4.60000            12.352058
# 8                    22                  4.80000            17.433809
# 9                    36                  4.20000            30.327968
# 10                   21                  4.70000            10.003064
# 11                   23                  4.70000            18.562450
# ...

# %%
a=df['Delivery_traveling_time'].unique()
a
#for i in a:
 #   print(a)
# Out:
# <FloatingArray>
# [  9.0,  28.0,  11.0,  15.0,  16.0,  25.0,  27.0,  24.0,  31.0,  13.0,
#  ...
#  776.0, 165.0, 576.0, 289.0, 418.0, -52.0, 620.0, 557.0, 703.0, 769.0]
# Length: 766, dtype: Float64

# %%
sns.displot(df['Delivery_traveling_time'])
# Out:
# C:\Users\ayush\anaconda3\Lib\site-packages\seaborn\distributions.py:499: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   pd.Index(edges, name="edges"),
# C:\Users\ayush\anaconda3\Lib\site-packages\seaborn\distributions.py:500: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   pd.Index(widths, name="widths"),

# %%
dataset.hist(figsize=(20,30))
# Out:
# array([[<Axes: title={'center': 'Delivery_person_Age'}>,
#         <Axes: title={'center': 'Delivery_person_Ratings'}>,
#         <Axes: title={'center': 'Restaurant_latitude'}>,
#         <Axes: title={'center': 'Restaurant_longitude'}>],
#        [<Axes: title={'center': 'Delivery_location_latitude'}>,
#         <Axes: title={'center': 'Delivery_location_longitude'}>,
#         <Axes: title={'center': 'Time_Orderd'}>,
#         <Axes: title={'center': 'Time_Order_picked'}>],
#        [<Axes: title={'center': 'Vehicle_condition'}>,
#         <Axes: title={'center': 'multiple_deliveries'}>,
#         <Axes: title={'center': 'Time_taken(min)'}>,
#         <Axes: title={'center': 'Food_Preparation_Time_minutes'}>],
#        [<Axes: title={'center': 'Delivery_traveling_time'}>, <Axes: >,
#         <Axes: >, <Axes: >]], dtype=object)

# %%
columns=['Weatherconditions']

dataset=pd.get_dummies(dataset,columns=columns,drop_first=True)

# %%
dataset.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                   37                      4.9            22.745049
# 1                   34                      4.5            12.913041
# 2                   23                      4.4            12.914264
# 3                   38                      4.7            11.003669
# 4                   32                      4.6            12.972793
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             75.892471                   22.765049
# 1             77.683237                   13.043041
# 2             77.678400                   12.924264
# 3             76.976494                   11.053669
# 4             80.249982                   13.012793
#
#    Delivery_location_longitude  Order_Date         Time_Orderd  \
# 0                    75.912471  19-03-2022 1900-01-01 11:30:00
# 1                    77.813237  25-03-2022 1900-01-01 19:45:00
# ...

# %%
#df['Road_traffic_density'].unique()
#df['Type_of_order'].unique()
#df['Type_of_vehicle'].unique()

df['Festival'].unique()
# Out:
# array(['No ', 'Yes '], dtype=object)

# %%
#one hot encoding categorical to numerical
columns=['Road_traffic_density']

dataset=pd.get_dummies(dataset,columns=columns,drop_first=True)

# %%
columns=['Type_of_order']

dataset=pd.get_dummies(dataset,columns=columns,drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[173], line 3
#       1 columns=['Type_of_order']
# ----> 3 dataset=pd.get_dummies(dataset,columns=columns,drop_first=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\encoding.py:146, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     144     raise TypeError("Input must be a list-like for parameter `columns`")
#     145 else:
# --> 146     data_to_encode = data[columns]
#     148 # validate prefixes and separator to avoid silently dropping cols
#     149 def check_len(item, name):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
# ...

# %%
columns=['Type_of_vehicle']

dataset=pd.get_dummies(dataset,columns=columns,drop_first=True)

# %%
dataset
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                       37                      4.9            22.745049
# 1                       34                      4.5            12.913041
# 2                       23                      4.4            12.914264
# 3                       38                      4.7            11.003669
# 4                       32                      4.6            12.972793
# ...                    ...                      ...                  ...
# 45588                   30                      4.8            26.902328
# 45589                   21                      4.6             0.000000
# 45590                   30                      4.9            13.022394
# 45591                   20                      4.7            11.001753
# 45592                   23                      4.9            23.351058
#
#        Restaurant_longitude  Delivery_location_latitude  \
# ...

# %%
dataset.shape
# Out:
# (45593, 30)
